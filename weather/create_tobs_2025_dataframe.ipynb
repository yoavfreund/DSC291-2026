# %% [markdown]
# # Create Weather DataFrame 1950-2025 with Dask
#
# Creates a wide-format dataframe with weather data from 1950-2025 including TOBS, TMAX, TMIN, PRCP, SNOW, SNWD measurements.
# Each row represents a station-year-measurement combination with 365 daily value columns.

# %%
import s3fs
import dask.dataframe as dd
import pandas as pd
import numpy as np
from datetime import datetime

# Import cluster management utilities
from cluster_utils import setup_dask_cluster

# Setup Dask cluster with 20 workers
cluster, client, cleanup_summary = setup_dask_cluster(
    n_workers=20,
    memory_per_worker='4GB',
    dashboard_port=8790,
    worker_port=8791
)

# Configure dask to use the cluster for all operations
import dask
dask.config.set({'scheduler': 'distributed'})

# Note: This will process 76 years × 6 measurements = 456 data collections
# Estimated processing time: 10-30 minutes depending on data availability
print(f"Starting weather data processing at {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
# Out:
# Checking for existing Dask clusters...
# No current client found
# 2025-10-17 01:14:40,041 - distributed.scheduler - INFO - State start
# 2025-10-17 01:14:40,043 - distributed.scheduler - INFO -   Scheduler at:     tcp://127.0.0.1:40247
# 2025-10-17 01:14:40,043 - distributed.scheduler - INFO -   dashboard at:            127.0.0.1:8790
# All existing clusters closed.
# Setting up new cluster with 20 workers...
# 2025-10-17 01:14:40,109 - distributed.nanny - INFO -         Start Nanny at: 'tcp://127.0.0.1:38221'
# 2025-10-17 01:14:40,111 - distributed.nanny - INFO -         Start Nanny at: 'tcp://127.0.0.1:39437'
# 2025-10-17 01:14:40,113 - distributed.nanny - INFO -         Start Nanny at: 'tcp://127.0.0.1:42715'
# 2025-10-17 01:14:40,115 - distributed.nanny - INFO -         Start Nanny at: 'tcp://127.0.0.1:33549'
# 2025-10-17 01:14:40,117 - distributed.nanny - INFO -         Start Nanny at: 'tcp://127.0.0.1:39073'
# 2025-10-17 01:14:40,119 - distributed.nanny - INFO -         Start Nanny at: 'tcp://127.0.0.1:37293'
# 2025-10-17 01:14:40,121 - distributed.nanny - INFO -         Start Nanny at: 'tcp://127.0.0.1:39867'
# 2025-10-17 01:14:40,124 - distributed.nanny - INFO -         Start Nanny at: 'tcp://127.0.0.1:34067'
# 2025-10-17 01:14:40,126 - distributed.nanny - INFO -         Start Nanny at: 'tcp://127.0.0.1:44761'
# 2025-10-17 01:14:40,129 - distributed.nanny - INFO -         Start Nanny at: 'tcp://127.0.0.1:46667'
# 2025-10-17 01:14:40,132 - distributed.nanny - INFO -         Start Nanny at: 'tcp://127.0.0.1:46727'
# 2025-10-17 01:14:40,134 - distributed.nanny - INFO -         Start Nanny at: 'tcp://127.0.0.1:37795'
# 2025-10-17 01:14:40,136 - distributed.nanny - INFO -         Start Nanny at: 'tcp://127.0.0.1:33547'
# 2025-10-17 01:14:40,139 - distributed.nanny - INFO -         Start Nanny at: 'tcp://127.0.0.1:44367'
# 2025-10-17 01:14:40,141 - distributed.nanny - INFO -         Start Nanny at: 'tcp://127.0.0.1:42015'
# 2025-10-17 01:14:40,216 - distributed.nanny - INFO -         Start Nanny at: 'tcp://127.0.0.1:37373'
# 2025-10-17 01:14:40,217 - distributed.nanny - INFO -         Start Nanny at: 'tcp://127.0.0.1:43941'
# 2025-10-17 01:14:40,220 - distributed.nanny - INFO -         Start Nanny at: 'tcp://127.0.0.1:40087'
# 2025-10-17 01:14:40,222 - distributed.nanny - INFO -         Start Nanny at: 'tcp://127.0.0.1:33961'
# 2025-10-17 01:14:40,225 - distributed.nanny - INFO -         Start Nanny at: 'tcp://127.0.0.1:44501'
# 2025-10-17 01:14:40,307 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-jrhjvreb', purging
# 2025-10-17 01:14:40,307 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-0njarai5', purging
# 2025-10-17 01:14:40,307 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-nn99u3az', purging
# 2025-10-17 01:14:40,307 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-zox6sf02', purging
# 2025-10-17 01:14:40,308 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-oxqh7lrf', purging
# 2025-10-17 01:14:40,308 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-s7zi5sm2', purging
# 2025-10-17 01:14:40,308 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-28dj309g', purging
# 2025-10-17 01:14:40,308 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-hbhskr3g', purging
# 2025-10-17 01:14:40,308 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-7td7k4n2', purging
# 2025-10-17 01:14:40,308 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-kyox7fnq', purging
# 2025-10-17 01:14:40,308 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-ihc6smq6', purging
# 2025-10-17 01:14:40,308 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-583ox4ru', purging
# 2025-10-17 01:14:40,308 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-owx8pkhi', purging
# 2025-10-17 01:14:40,308 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-hlzkd4rc', purging
# 2025-10-17 01:14:40,308 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-yywlcy4q', purging
# 2025-10-17 01:14:40,308 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-egzrntrz', purging
# 2025-10-17 01:14:40,308 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-wqt9_bm4', purging
# 2025-10-17 01:14:40,308 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-ps0lzeju', purging
# 2025-10-17 01:14:40,308 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-bwyactzb', purging
# 2025-10-17 01:14:40,308 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-5_texe8f', purging
# 2025-10-17 01:14:40,308 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-zkrzfjk7', purging
# 2025-10-17 01:14:40,308 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-bbin9g8w', purging
# 2025-10-17 01:14:40,309 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-6pf__jlr', purging
# 2025-10-17 01:14:40,309 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-21pie5kt', purging
# 2025-10-17 01:14:40,309 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-0jy61dwa', purging
# 2025-10-17 01:14:40,309 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-ehi46akw', purging
# 2025-10-17 01:14:40,309 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-3nwq0hx5', purging
# 2025-10-17 01:14:40,309 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-1jgjifh_', purging
# /home/yfreund/.conda/envs/dask-tutorial/lib/python3.10/site-packages/distributed/node.py:182: UserWarning: Port 8791 is already in use.
# Perhaps you already have a cluster running?
# Hosting the HTTP server on port 33311 instead
#   warnings.warn(
# /home/yfreund/.conda/envs/dask-tutorial/lib/python3.10/site-packages/distributed/node.py:182: UserWarning: Port 8791 is already in use.
# Perhaps you already have a cluster running?
# Hosting the HTTP server on port 44749 instead
#   warnings.warn(
# /home/yfreund/.conda/envs/dask-tutorial/lib/python3.10/site-packages/distributed/node.py:182: UserWarning: Port 8791 is already in use.
# Perhaps you already have a cluster running?
# Hosting the HTTP server on port 44847 instead
#   warnings.warn(
# /home/yfreund/.conda/envs/dask-tutorial/lib/python3.10/site-packages/distributed/node.py:182: UserWarning: Port 8791 is already in use.
# Perhaps you already have a cluster running?
# Hosting the HTTP server on port 43463 instead
#   warnings.warn(
# /home/yfreund/.conda/envs/dask-tutorial/lib/python3.10/site-packages/distributed/node.py:182: UserWarning: Port 8791 is already in use.
# Perhaps you already have a cluster running?
# Hosting the HTTP server on port 33349 instead
#   warnings.warn(
# /home/yfreund/.conda/envs/dask-tutorial/lib/python3.10/site-packages/distributed/node.py:182: UserWarning: Port 8791 is already in use.
# Perhaps you already have a cluster running?
# Hosting the HTTP server on port 43055 instead
#   warnings.warn(
# /home/yfreund/.conda/envs/dask-tutorial/lib/python3.10/site-packages/distributed/node.py:182: UserWarning: Port 8791 is already in use.
# Perhaps you already have a cluster running?
# Hosting the HTTP server on port 41755 instead
#   warnings.warn(
# /home/yfreund/.conda/envs/dask-tutorial/lib/python3.10/site-packages/distributed/node.py:182: UserWarning: Port 8791 is already in use.
# Perhaps you already have a cluster running?
# Hosting the HTTP server on port 40167 instead
#   warnings.warn(
# /home/yfreund/.conda/envs/dask-tutorial/lib/python3.10/site-packages/distributed/node.py:182: UserWarning: Port 8791 is already in use.
# Perhaps you already have a cluster running?
# Hosting the HTTP server on port 40145 instead
#   warnings.warn(
# /home/yfreund/.conda/envs/dask-tutorial/lib/python3.10/site-packages/distributed/node.py:182: UserWarning: Port 8791 is already in use.
# Perhaps you already have a cluster running?
# Hosting the HTTP server on port 38583 instead
#   warnings.warn(
# /home/yfreund/.conda/envs/dask-tutorial/lib/python3.10/site-packages/distributed/node.py:182: UserWarning: Port 8791 is already in use.
# Perhaps you already have a cluster running?
# Hosting the HTTP server on port 39211 instead
#   warnings.warn(
# /home/yfreund/.conda/envs/dask-tutorial/lib/python3.10/site-packages/distributed/node.py:182: UserWarning: Port 8791 is already in use.
# Perhaps you already have a cluster running?
# Hosting the HTTP server on port 41869 instead
#   warnings.warn(
# /home/yfreund/.conda/envs/dask-tutorial/lib/python3.10/site-packages/distributed/node.py:182: UserWarning: Port 8791 is already in use.
# Perhaps you already have a cluster running?
# Hosting the HTTP server on port 42435 instead
#   warnings.warn(
# /home/yfreund/.conda/envs/dask-tutorial/lib/python3.10/site-packages/distributed/node.py:182: UserWarning: Port 8791 is already in use.
# Perhaps you already have a cluster running?
# Hosting the HTTP server on port 37645 instead
#   warnings.warn(
# /home/yfreund/.conda/envs/dask-tutorial/lib/python3.10/site-packages/distributed/node.py:182: UserWarning: Port 8791 is already in use.
# Perhaps you already have a cluster running?
# Hosting the HTTP server on port 37783 instead
#   warnings.warn(
# /home/yfreund/.conda/envs/dask-tutorial/lib/python3.10/site-packages/distributed/node.py:182: UserWarning: Port 8791 is already in use.
# Perhaps you already have a cluster running?
# Hosting the HTTP server on port 37467 instead
#   warnings.warn(
# /home/yfreund/.conda/envs/dask-tutorial/lib/python3.10/site-packages/distributed/node.py:182: UserWarning: Port 8791 is already in use.
# Perhaps you already have a cluster running?
# Hosting the HTTP server on port 38099 instead
#   warnings.warn(
# /home/yfreund/.conda/envs/dask-tutorial/lib/python3.10/site-packages/distributed/node.py:182: UserWarning: Port 8791 is already in use.
# Perhaps you already have a cluster running?
# Hosting the HTTP server on port 45383 instead
#   warnings.warn(
# /home/yfreund/.conda/envs/dask-tutorial/lib/python3.10/site-packages/distributed/node.py:182: UserWarning: Port 8791 is already in use.
# Perhaps you already have a cluster running?
# Hosting the HTTP server on port 44297 instead
#   warnings.warn(
# 2025-10-17 01:14:40,586 - distributed.worker - INFO -       Start worker at:      tcp://127.0.0.1:44135
# 2025-10-17 01:14:40,586 - distributed.worker - INFO -          Listening to:      tcp://127.0.0.1:44135
# 2025-10-17 01:14:40,586 - distributed.worker - INFO -           Worker name:                          3
# 2025-10-17 01:14:40,586 - distributed.worker - INFO
- distributed.core - INFO - Starting established connection to tcp://127.0.0.1:46254
# 2025-10-17 01:14:40,821 - distributed.worker - INFO - -------------------------------------------------
# 2025-10-17 01:14:40,822 - distributed.core - INFO - Starting established connection to tcp://127.0.0.1:40247
# 2025-10-17 01:14:40,826 - distributed.worker - INFO -       Start worker at:      tcp://127.0.0.1:36101
# 2025-10-17 01:14:40,826 - distributed.worker - INFO -          Listening to:      tcp://127.0.0.1:36101
# 2025-10-17 01:14:40,826 - distributed.worker - INFO -           Worker name:                         16
# 2025-10-17 01:14:40,826 - distributed.worker - INFO -          dashboard at:            127.0.0.1:37783
# 2025-10-17 01:14:40,826 - distributed.worker - INFO - Waiting to connect to:      tcp://127.0.0.1:40247
# 2025-10-17 01:14:40,826 - distributed.worker - INFO - -------------------------------------------------
# 2025-10-17 01:14:40,826 - distributed.worker - INFO -               Threads:                          1
# 2025-10-17 01:14:40,826 - distributed.worker - INFO -                Memory:                   3.73 GiB
# 2025-10-17 01:14:40,826 - distributed.worker - INFO -       Local Directory: /tmp/dask-worker-space/worker-fpiv6z0k
# 2025-10-17 01:14:40,826 - distributed.worker - INFO - -------------------------------------------------
# 2025-10-17 01:14:40,828 - distributed.scheduler - INFO - Register worker <WorkerState 'tcp://127.0.0.1:36101', name: 16, status: init, memory: 0, processing: 0>
# 2025-10-17 01:14:40,828 - distributed.scheduler - INFO - Starting worker compute stream, tcp://127.0.0.1:36101
# 2025-10-17 01:14:40,829 - distributed.worker - INFO -         Registered to:      tcp://127.0.0.1:40247
# 2025-10-17 01:14:40,829 - distributed.core - INFO - Starting established connection to tcp://127.0.0.1:46266
# 2025-10-17 01:14:40,829 - distributed.worker - INFO - -------------------------------------------------
# 2025-10-17 01:14:40,829 - distributed.core - INFO - Starting established connection to tcp://127.0.0.1:40247
# 2025-10-17 01:14:40,840 - distributed.scheduler - INFO - Receive client connection: Client-2f3a05a7-ab18-11f0-a982-5811224a71df
# 2025-10-17 01:14:40,841 - distributed.core - INFO - Starting established connection to tcp://127.0.0.1:46276
# ✓ Dask cluster created with 20 workers
# ✓ Dashboard available at: http://127.0.0.1:8790/status
# ✓ Total workers: 20
# ✓ Cores per worker: {'tcp://127.0.0.1:32935': 1, 'tcp://127.0.0.1:33023': 1, 'tcp://127.0.0.1:33083': 1, 'tcp://127.0.0.1:34133': 1, 'tcp://127.0.0.1:34233': 1, 'tcp://127.0.0.1:35403': 1, 'tcp://127.0.0.1:35709': 1, 'tcp://127.0.0.1:36101': 1, 'tcp://127.0.0.1:37337': 1, 'tcp://127.0.0.1:38009': 1, 'tcp://127.0.0.1:38439': 1, 'tcp://127.0.0.1:39319': 1, 'tcp://127.0.0.1:40031': 1, 'tcp://127.0.0.1:40867': 1, 'tcp://127.0.0.1:41071': 1, 'tcp://127.0.0.1:41255': 1, 'tcp://127.0.0.1:42241': 1, 'tcp://127.0.0.1:43071': 1, 'tcp://127.0.0.1:44135': 1, 'tcp://127.0.0.1:44139': 1}
# ✓ Total memory available: 80.0 GB
# ✓ Cluster test computation successful: 4981.52
# Starting weather data processing at 2025-10-17 01:14:41

# %%
# Load weather data for all years 1950-2025 using Dask
s3 = s3fs.S3FileSystem(anon=True)
bucket_path = 's3://noaa-ghcn-pds/parquet/by_year/'
measurements = ['TOBS', 'TMAX', 'TMIN', 'PRCP', 'SNOW', 'SNWD']

# Collect all data files (this may take a few minutes)
all_files = []
print("Collecting file paths...")
for year in range(1950, 2026):
    for measurement in measurements:
        file_path = f"{bucket_path}YEAR={year}/ELEMENT={measurement}/"
        try:
            files = s3.glob(f"{file_path}*.parquet")
            all_files.extend([f"s3://{f}" for f in files])
        except:
            continue
    if year % 10 == 0:  # Progress indicator
        print(f"  Processed years up to {year}...")

print(f"Found {len(all_files)} parquet files to process")

# Load all data using Dask (lazy loading)
df_long = dd.read_parquet(all_files, storage_options={'anon': True})
print(f"Loaded {len(df_long):,} rows from {df_long['ID'].nunique().compute():,} stations")
# Out:
# Collecting file paths...
#   Processed years up to 1950...
#   Processed years up to 1960...
#   Processed years up to 1970...
#   Processed years up to 1980...
#   Processed years up to 1990...
#   Processed years up to 2000...
#   Processed years up to 2010...
#   Processed years up to 2020...
# Found 4751 parquet files to process

# %%
df_long.head()

# %%
# Transform to wide format using Dask
df_long['date_dt'] = dd.to_datetime(df_long['DATE'], format='%Y%m%d')
df_long['day_of_year'] = df_long['date_dt'].dt.dayofyear
df_long['year'] = df_long['date_dt'].dt.year

# Use dask pivot operation instead of pandas
# First, select the columns we need for pivoting
df_pivot = df_long[['ID', 'year', 'ELEMENT', 'day_of_year', 'DATA_VALUE']].copy()

# Create a unique identifier for each group
df_pivot['group_id'] = df_pivot['ID'].astype(str) + '_' + df_pivot['year'].astype(str) + '_' + df_pivot['ELEMENT']

# %%
# Pivot using dask groupby and unstack operations
df_wide = df_pivot.groupby(['group_id', 'day_of_year'])['DATA_VALUE'].first().unstack(fill_value=np.nan)

# %%
# Reset index to get group_id as a column
df_wide = df_wide.reset_index()

# Split the group_id back into separate columns
df_wide[['ID', 'year', 'ELEMENT']] = df_wide['group_id'].str.split('_', expand=True)
df_wide['ID'] = df_wide['ID'].astype(int)
df_wide['year'] = df_wide['year'].astype(int)

# Drop the temporary group_id column
df_wide = df_wide.drop('group_id', axis=1)

# Ensure all days 1-365 exist as columns
day_columns = list(range(1, 366))
for day in day_columns:
    if day not in df_wide.columns:
        df_wide[day] = np.nan

# Reorder columns to have ID, year, ELEMENT first, then days 1-365
columns_order = ['ID', 'year', 'ELEMENT'] + day_columns
df_wide = df_wide[columns_order]

# Sort and rename columns
day_cols = sorted([col for col in df_wide.columns if isinstance(col, int)])
df_wide = df_wide[['ID', 'year', 'ELEMENT'] + day_cols]
df_wide.columns = ['station_id', 'year', 'measurement'] + [f'day_{i}' for i in range(1, 366)]

print(f"Created wide format: {df_wide.shape[0]:,} station-year-measurement combinations × {df_wide.shape[1]} columns")

# %%
df_wide.head()

# %%
# Save to file
output_file = 'weather_1950_2025_wide.parquet'
df_wide.to_parquet(output_file, index=False)
print(f"Saved to {output_file}")

# Show summary of measurements and years
print(f"\nSummary:")
print(f"Measurements included: {sorted(df_wide['measurement'].unique())}")
print(f"Years covered: {df_wide['year'].min()} to {df_wide['year'].max()}")
print(f"Total unique stations: {df_wide['station_id'].nunique():,}")
print(f"Total combinations: {len(df_wide):,}")
print(f"Processing completed at {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")

# %% [markdown]
# ## Summary
#
# Dataframe saved as `weather_1950_2025_wide.parquet` with:
# - **Index**: `station_id`, `year`, `measurement` (where measurement is TOBS, TMAX, TMIN, PRCP, SNOW, or SNWD)
# - **Columns**: `day_1` through `day_365`
# - **Values**: Weather observations (units vary by measurement type)
# - **Time Range**: 1950-2025 (76 years)
# - **Processed using Dask DataFrames** for efficient handling of large datasets
#
# ### Measurement Types:
# - **TOBS**: Temperature at observation time (tenths of degrees C)
# - **TMAX**: Maximum temperature (tenths of degrees C)
# - **TMIN**: Minimum temperature (tenths of degrees C)
# - **PRCP**: Precipitation (tenths of mm)
# - **SNOW**: Snowfall (mm)
# - **SNWD**: Snow depth (mm)

# %%
# Clean up cluster
from cluster_utils import close_dask_cluster
close_dask_cluster(cluster, client)
