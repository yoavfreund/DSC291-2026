# %% [markdown]
# # Folium Demo - Interactive Maps
#
# This notebook demonstrates how to use folium to create interactive maps for weather data visualization.
# Note: We switched from pyleaflet to folium because pyleaflet has limited functionality.

# %%
import folium
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime

print("Folium version:", folium.__version__)
print("Ready to create interactive maps!")
# Out:
# Folium version: 0.20.0
# Ready to create interactive maps!

# %% [markdown]
# ## Basic Map Creation

# %%
# Create a basic map centered on New York City
m = folium.Map(location=[40.7128, -74.0060], zoom_start=10)
# Change center location from NYC to Chicago
m = folium.Map(location=[41.8781, -87.6298], zoom_start=10)

# Add a marker for NYC
# folium.Marker([40.7128, -74.0060], popup="New York City").add_to(m)

# Display the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_dd2f96ef5ea6ad4458ec88bf7c0e2b20 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_dd2f96ef5ea6ad4458ec88bf7c0e2b20&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_dd2f96ef5ea6ad4458ec88bf7c0e2b20 = L.map(
#                 &quot;map_dd2f96ef5ea6ad4458ec88bf7c0e2b20&quot;,
#                 {
#                     center: [41.8781, -87.6298],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a65fdefdfde3314475153a322ee7ada4 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_a65fdefdfde3314475153a322ee7ada4.addTo(map_dd2f96ef5ea6ad4458ec88bf7c0e2b20);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Multiple Markers and Custom Icons

# %%
# Create a map with multiple weather stations
m2 = folium.Map(location=[39.8283, -98.5795], zoom_start=4)  # Center on USA

# Sample weather station data
stations = [
    {"name": "New York", "lat": 40.7128, "lon": -74.0060, "temp": 15.5},
    {"name": "Los Angeles", "lat": 34.0522, "lon": -118.2437, "temp": 22.3},
    {"name": "Chicago", "lat": 41.8781, "lon": -87.6298, "temp": 8.7},
    {"name": "Miami", "lat": 25.7617, "lon": -80.1918, "temp": 28.9},
    {"name": "Seattle", "lat": 47.6062, "lon": -122.3321, "temp": 12.1}
]

# Add markers for each station
for station in stations:
    popup_text = f"""
    <b>{station['name']}</b><br>
    Temperature: {station['temp']}°C<br>
    Coordinates: {station['lat']:.4f}, {station['lon']:.4f}
    """
    folium.Marker([station['lat'], station['lon']], popup=popup_text).add_to(m2)

m2
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_10ff64875f02b2a00389f7b1561f2717 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_10ff64875f02b2a00389f7b1561f2717&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_10ff64875f02b2a00389f7b1561f2717 = L.map(
#                 &quot;map_10ff64875f02b2a00389f7b1561f2717&quot;,
#                 {
#                     center: [39.8283, -98.5795],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 4,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b271c5ca2799c0715e2aba2fe4068c56 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_b271c5ca2799c0715e2aba2fe4068c56.addTo(map_10ff64875f02b2a00389f7b1561f2717);
#
#
#             var marker_f49f739dd5a791011ac6d87114a1d8e3 = L.marker(
#                 [40.7128, -74.006],
#                 {
# }
#             ).addTo(map_10ff64875f02b2a00389f7b1561f2717);
#
#
#         var popup_958060f86f0f64a1801286cab4b9ca07 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_db9a8ccf5477575e27270153ad7805b4 = $(`&lt;div id=&quot;html_db9a8ccf5477575e27270153ad7805b4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;b&gt;New York&lt;/b&gt;&lt;br&gt;     Temperature: 15.5°C&lt;br&gt;     Coordinates: 40.7128, -74.0060     &lt;/div&gt;`)[0];
#                 popup_958060f86f0f64a1801286cab4b9ca07.setContent(html_db9a8ccf5477575e27270153ad7805b4);
#
#
#
#         marker_f49f739dd5a791011ac6d87114a1d8e3.bindPopup(popup_958060f86f0f64a1801286cab4b9ca07)
#         ;
#
#
#
#
#             var marker_d2e00ce644512cd2f2d3be0e08bed1c0 = L.marker(
#                 [34.0522, -118.2437],
#                 {
# }
#             ).addTo(map_10ff64875f02b2a00389f7b1561f2717);
#
#
#         var popup_d4ca16fc0b416ed9b08fb6f1cfcda3d9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b474bd34772981f91b994026f02fbb92 = $(`&lt;div id=&quot;html_b474bd34772981f91b994026f02fbb92&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;b&gt;Los Angeles&lt;/b&gt;&lt;br&gt;     Temperature: 22.3°C&lt;br&gt;     Coordinates: 34.0522, -118.2437     &lt;/div&gt;`)[0];
#                 popup_d4ca16fc0b416ed9b08fb6f1cfcda3d9.setContent(html_b474bd34772981f91b994026f02fbb92);
#
#
#
#         marker_d2e00ce644512cd2f2d3be0e08bed1c0.bindPopup(popup_d4ca16fc0b416ed9b08fb6f1cfcda3d9)
#         ;
#
#
#
#
#             var marker_9d9c5bec3e9e23727a9a89ae4f61c1a8 = L.marker(
#                 [41.8781, -87.6298],
#                 {
# }
#             ).addTo(map_10ff64875f02b2a00389f7b1561f2717);
#
#
#         var popup_164c522a9aef64d8f03261a1def7a055 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9fec93819ebf469149d6b2cdc1d49f4f = $(`&lt;div id=&quot;html_9fec93819ebf469149d6b2cdc1d49f4f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;b&gt;Chicago&lt;/b&gt;&lt;br&gt;     Temperature: 8.7°C&lt;br&gt;     Coordinates: 41.8781, -87.6298     &lt;/div&gt;`)[0];
#                 popup_164c522a9aef64d8f03261a1def7a055.setContent(html_9fec93819ebf469149d6b2cdc1d49f4f);
#
#
#
#         marker_9d9c5bec3e9e23727a9a89ae4f61c1a8.bindPopup(popup_164c522a9aef64d8f03261a1def7a055)
#         ;
#
#
#
#
#             var marker_46cfc5a15f1a383c978984d3c0a55f9a = L.marker(
#                 [25.7617, -80.1918],
#                 {
# }
#             ).addTo(map_10ff64875f02b2a00389f7b1561f2717);
#
#
#         var popup_c6c655a2d0738317764e0ce669b4610b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_99979448c2682a63ea2836ba03c1bde4 = $(`&lt;div id=&quot;html_99979448c2682a63ea2836ba03c1bde4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;b&gt;Miami&lt;/b&gt;&lt;br&gt;     Temperature: 28.9°C&lt;br&gt;     Coordinates: 25.7617, -80.1918     &lt;/div&gt;`)[0];
#                 popup_c6c655a2d0738317764e0ce669b4610b.setContent(html_99979448c2682a63ea2836ba03c1bde4);
#
#
#
#         marker_46cfc5a15f1a383c978984d3c0a55f9a.bindPopup(popup_c6c655a2d0738317764e0ce669b4610b)
#         ;
#
#
#
#
#             var marker_9102769f79ada178002401414a88924d = L.marker(
#                 [47.6062, -122.3321],
#                 {
# }
#             ).addTo(map_10ff64875f02b2a00389f7b1561f2717);
#
#
#         var popup_48d617e6c6648dda2023e0afad8edf54 = L.popup({
#   &quot;maxWidth&quot;: &quot

# %% [markdown]
# ## Color-Coded Markers by Temperature

# %%
# Create a map with color-coded temperature markers
m3 = folium.Map(location=[39.8283, -98.5795], zoom_start=4)

def get_temp_color(temp):
    """Get color based on temperature"""
    if temp < 10:
        return 'blue'
    elif temp < 20:
        return 'green'
    elif temp < 30:
        return 'orange'
    else:
        return 'red'

# Add color-coded markers
for station in stations:
    color = get_temp_color(station['temp'])
    popup_text = f"""
    <div style='text-align: center;'>
        <h3 style='color: {color};'>{station['name']}</h3>
        <p><strong>Temperature:</strong> {station['temp']}°C</p>
        <p><strong>Status:</strong> {'Hot' if station['temp'] > 25 else 'Cool' if station['temp'] < 15 else 'Moderate'}</p>
    </div>
    """
    folium.Marker([station['lat'], station['lon']], 
                  popup=popup_text, 
                  icon=folium.Icon(color=color)).add_to(m3)

m3
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_420f34e3e552c41959f8db4969230e24 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_420f34e3e552c41959f8db4969230e24&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_420f34e3e552c41959f8db4969230e24 = L.map(
#                 &quot;map_420f34e3e552c41959f8db4969230e24&quot;,
#                 {
#                     center: [39.8283, -98.5795],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 4,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1ccd7983b9bf74ee37dc01575cd8be69 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_1ccd7983b9bf74ee37dc01575cd8be69.addTo(map_420f34e3e552c41959f8db4969230e24);
#
#
#             var marker_fb3535fdf9338434e6343001f2e7e872 = L.marker(
#                 [40.7128, -74.006],
#                 {
# }
#             ).addTo(map_420f34e3e552c41959f8db4969230e24);
#
#
#             var icon_0ca49901883536481ffbc58ac098882d = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_29563dedbd5d3fb13630189fa049ae19 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_05e8ab67842e47b3279793db0b45c2bb = $(`&lt;div id=&quot;html_05e8ab67842e47b3279793db0b45c2bb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;div style=&#x27;text-align: center;&#x27;&gt;         &lt;h3 style=&#x27;color: green;&#x27;&gt;New York&lt;/h3&gt;         &lt;p&gt;&lt;strong&gt;Temperature:&lt;/strong&gt; 15.5°C&lt;/p&gt;         &lt;p&gt;&lt;strong&gt;Status:&lt;/strong&gt; Moderate&lt;/p&gt;     &lt;/div&gt;     &lt;/div&gt;`)[0];
#                 popup_29563dedbd5d3fb13630189fa049ae19.setContent(html_05e8ab67842e47b3279793db0b45c2bb);
#
#
#
#         marker_fb3535fdf9338434e6343001f2e7e872.bindPopup(popup_29563dedbd5d3fb13630189fa049ae19)
#         ;
#
#
#
#
#                 marker_fb3535fdf9338434e6343001f2e7e872.setIcon(icon_0ca49901883536481ffbc58ac098882d);
#
#
#             var marker_9b6cb5175fa58c7021be2858e5041c24 = L.marker(
#                 [34.0522, -118.2437],
#                 {
# }
#             ).addTo(map_420f34e3e552c41959f8db4969230e24);
#
#
#             var icon_930c4395a7995d392fdb70c86e6e2b70 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;orange&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_4617c2632214ca30d40fc55a3dd6b420 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8331bebcbd3a8516bd4e762b16a8bb5e = $(`&lt;div id=&quot;html_8331bebcbd3a8516bd4e762b16a8bb5e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;div style=&#x27;text-align: center;&#x27;&gt;         &lt;h3 style=&#x27;color: orange;&#x27;&gt;Los Angeles&lt;/h3&gt;         &lt;p&gt;&lt;strong&gt;Temperature:&lt;/strong&gt; 22.3°C&lt;/p&gt;         &lt;p&gt;&lt;strong&gt;Status:&lt;/strong&gt; Moderate&lt;/p&gt;     &lt;/div&gt;     &lt;/div&gt;`)[0];
#                 popup_4617c2632214ca30d40fc55a3dd6b420.setContent(html_8331bebcbd3a8516bd4e762b16a8bb5e);
#
#
#
#         marker_9b6cb5175fa58c7021be2858e5041c24.bindPopup(popup_4617c2632214ca30d40fc55a3dd6b420)
#         ;
#
#
#
#
#                 marker_9b6cb5175fa58c7021be2858e5041c24.setIcon(icon_930c4395a7995d392fdb70c86e6e2b70);
#
#
#             var marker_47c324deb8f8d549be13ace0269e0564 = L.marker(
#                 [41.8781, -87.6298],
#                 {
# }
#             ).addTo(map_420f34e3e552c41959f8db4969230e24);
#
#
#             var icon_f30f7658223701c17d27def6a691e62f = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_8f182dc5f526329ca2c8d1ba0a38ccea = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_51743f34eacb50d01710062eea7b9322 = $(`&lt;div id

# %% [markdown]
# ## Interactive Heatmap

# %%
# Create a heatmap of temperature data
m4 = folium.Map(location=[39.8283, -98.5795], zoom_start=4)

# Generate more data points for a better heatmap
np.random.seed(42)
n_points = 50
lat_range = (25, 50)
lon_range = (-125, -65)

# Generate random points with temperature data
heatmap_data = []
for i in range(n_points):
    lat = np.random.uniform(lat_range[0], lat_range[1])
    lon = np.random.uniform(lon_range[0], lon_range[1])
    # Temperature varies with latitude (colder in north)
    temp = 30 - (lat - 25) * 0.5 + np.random.normal(0, 5)
    heatmap_data.append([lat, lon, temp])

# Add heatmap layer using folium's HeatMap
from folium.plugins import HeatMap
HeatMap(heatmap_data, radius=20, blur=15, max_zoom=1).add_to(m4)

# Add some markers for reference
for i, (lat, lon, temp) in enumerate(heatmap_data[::10]):  # Every 10th point
    folium.Marker([lat, lon], popup=f"Temp: {temp:.1f}°C").add_to(m4)

m4
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_43b84b4d6df6d8ce51999b6bdabc5b65 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_43b84b4d6df6d8ce51999b6bdabc5b65&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_43b84b4d6df6d8ce51999b6bdabc5b65 = L.map(
#                 &quot;map_43b84b4d6df6d8ce51999b6bdabc5b65&quot;,
#                 {
#                     center: [39.8283, -98.5795],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 4,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_57526e90a14e28cf815e71ecadfa4b39 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_57526e90a14e28cf815e71ecadfa4b39.addTo(map_43b84b4d6df6d8ce51999b6bdabc5b65);
#
#
#             var heat_map_15f45390954cc636a10f04fa37ef2a0f = L.heatLayer(
#                 [[34.36350297118406, -67.95714161540502, 28.55669120491143], [28.900466011060914, -115.64032877982784, 35.66491627650967], [26.452090304204987, -73.02943125350389, 37.17001892543446], [25.514612357395063, -66.80540887028033, 33.57986746706701], [45.81106602001054, -112.25965335930343, 17.277378525932416], [32.60605607398844, -93.51461410206574, 23.868323195154495], [35.7986254660529, -107.52625158811749, 19.536531665301432], [32.30361621338045, -103.0182894023785, 27.919428556286142], [36.4017496054259, -77.88944231641918, 24.63676622072667], [39.81036422155106, -122.21297523680013, 15.471076958157186], [40.18862129753596, -114.76855257876251, 19.402495901637995], [42.10582566280392, -98.59085037562392, 19.988618419631656], [28.05095587111947, -95.28938539332378, 32.58724662495621], [32.792776902235275, -93.79591872933135, 19.99939329902725], [38.667756983581995, -113.90873266846837, 26.858454408186056], [27.212312551297988, -113.24102825485129, 29.75068513030086], [26.13068222276345, -105.48018015420413, 22.042048936781136], [45.718437728798236, -103.59480039838465, 16.04156009362734], [32.02336274218452, -92.43823501050508, 28.108738475881715], [26.863766091994272, -65.78678380396896, 27.14270555192128], [44.306119232416435, -113.07705910794965, 25.501937996271536], [44.281758667148644, -120.55732089595458, 25.015521262006672], [33.96164321360681, -118.04785642849222, 27.175495550214414], [33.27245062131623, -121.18649898283859, 30.74150032495368], [32.774558042891556, -105.48900067839517, 30.175350090525214], [47.18031856440817, -96.66710449028304, 25.69104086065003], [27.98985614845754, -82.2053127666203, 30.3120499533133], [44.27417949886403, -95.37226421813656, 28.05309308289783], [38.06832073454985, -99.34753889848702, 23.901074973915932], [32.85889952690817, -94.48575853011783, 24.57551348421658], [47.689161848152324, -110.04246625106751, 26.044889299631418], [30.71995413729056, -120.38120541027241, 24.548671839986483], [32.2437863228442, -115.32672276475974, 30.95511742708827], [45.09180192247786, -113.80579646683785, 21.59785458705949], [47.313974962249446, -92.63946548506095, 15.332747049488514], [30.698379063548543, -99.37353268242462, 25.512499735236887], [45.45036914806233, -73.35616500461938, 19.80038270918114], [35.43527507871947, -111.67353137175618, 23.60942679376453], [27.99663418334207, -104.74308971578232, 27.69525434999892], [37.96976554358415, -82.81886246628933, 25.535371512280616], [34.09074005948235, -66.69307503674236, 15.860773893763618], [32.12101235943669, -122.78678315872803, 26.30692444303557], [40.23910834949742, -94.83925860626832, 21.418641001345677], [28.622371802280576, -95.63283438334622, 29.696550810527775], [49.641261352765014, -110.47668370930998, 23.393483396192597], [30.940938599809993, -81.30701908328842, 30.789195863528874], [34.19457831798133, -87.06165016438524, 28.336996310010687], [27.257244251360206, -74.88185026464572, 39.82365600336979], [33.0195016242934, -113.80888937600875, 26.488506013291506], [41.939109046057055, -124.00473026432863, 19.013067206390478]],
#                 {
#   &quot;minOpacity&quot;: 0.5,
#   &quot;maxZoom&quot;: 1,
#   &quot;radius&quot;: 20,
#   &quot;blur&quot;: 15,
# }
#             );
#
#
#             heat_map_15f45390954cc636a10f04fa37ef2a0f.addTo(map_43b84b4d6df6d8ce51999b6bdabc5b65);
#
#
#             var marker_72b32aff86dac2cea186ea5b1e905dda = L.marker(
#                 [34.36350297118406, -67.95714161540502],
#                 {
# }
#             ).addTo(map_43b84b4d6df6d8ce51999b6bdabc5b65);
#
#
#         var popup_5195b6450f48666e9fb5b2b8e832842b = L.popup({
#   &quot;maxWidth&quot;: &quo

# %% [markdown]
# ## Map Layers and Controls

# %%
# Create a map with multiple layers and controls
m5 = folium.Map(location=[39.8283, -98.5795], zoom_start=4)

# Add different base layers (folium uses different approach)
# Note: Folium handles base layers differently than pyleaflet

# Add circles to show temperature range
for station in stations:
    # Circle size based on temperature
    radius = station['temp'] * 1000  # Scale for visibility
    
    # Add circle using folium
    folium.CircleMarker([station['lat'], station['lon']], 
                       radius=radius/1000,  # Scale down for folium
                       color=get_temp_color(station['temp']),
                       fill=True,
                       popup=f"{station['name']}: {station['temp']}°C").add_to(m5)

# Add a rectangle for a region of interest
folium.Rectangle([[35, -100], [45, -80]], 
                color='red', 
                fill=False, 
                popup="Analysis Region").add_to(m5)

m5
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ffdfa90b78c888c923c79d6d295d04bd {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ffdfa90b78c888c923c79d6d295d04bd&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ffdfa90b78c888c923c79d6d295d04bd = L.map(
#                 &quot;map_ffdfa90b78c888c923c79d6d295d04bd&quot;,
#                 {
#                     center: [39.8283, -98.5795],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 4,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4db9005703d4f32e24543a2f4d68cf59 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_4db9005703d4f32e24543a2f4d68cf59.addTo(map_ffdfa90b78c888c923c79d6d295d04bd);
#
#
#             var circle_marker_d5586bc0c7da33a3d98a1472a4dd54f7 = L.circleMarker(
#                 [40.7128, -74.006],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 15.5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_ffdfa90b78c888c923c79d6d295d04bd);
#
#
#         var popup_e64cf25a100b8d10f2b9e91239f0a9e7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_04108fc6b13910c1d2e14b3bd7e03edf = $(`&lt;div id=&quot;html_04108fc6b13910c1d2e14b3bd7e03edf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;New York: 15.5°C&lt;/div&gt;`)[0];
#                 popup_e64cf25a100b8d10f2b9e91239f0a9e7.setContent(html_04108fc6b13910c1d2e14b3bd7e03edf);
#
#
#
#         circle_marker_d5586bc0c7da33a3d98a1472a4dd54f7.bindPopup(popup_e64cf25a100b8d10f2b9e91239f0a9e7)
#         ;
#
#
#
#
#             var circle_marker_2cbf4bafe18ff1a8c931b86155abcc2b = L.circleMarker(
#                 [34.0522, -118.2437],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;orange&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;orange&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 22.3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_ffdfa90b78c888c923c79d6d295d04bd);
#
#
#         var popup_3848a9ecec293c64db2eba2b4925228f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6b75b431aa29fa99ca81179a18d14865 = $(`&lt;div id=&quot;html_6b75b431aa29fa99ca81179a18d14865&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Los Angeles: 22.3°C&lt;/div&gt;`)[0];
#                 popup_3848a9ecec293c64db2eba2b4925228f.setContent(html_6b75b431aa29fa99ca81179a18d14865);
#
#
#
#         circle_marker_2cbf4bafe18ff1a8c931b86155abcc2b.bindPopup(popup_3848a9ecec293c64db2eba2b4925228f)
#         ;
#
#
#
#
#             var circle_marker_bdd6de8b38270ddb62a68ebde23bd886 = L.circleMarker(
#                 [41.8781, -87.6298],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 8.7, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_ffdfa90b78c888c923c79d6d295d04bd);
#
#
#         var popup_8cc52e2720485dff32adf9d6976f2834 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8255a23aef89b464c1480ba18f8c3f12 = $(`&lt;div id=&quot;html_8255a23aef89b464c1480ba18f8c3f12&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Chicago: 8.7°C&lt;/div&gt;`)[0];
#                 popup_8cc52e2720485dff32adf9d6976f2834.setContent(html_8255a23aef89b464c1480ba18f8c3f12);
#
#
#
#         circle_marker_bdd6de8b38270ddb62a68ebde23bd886.bindPopup(popup_8cc52e2720485dff32adf9d6976f2834)
#         ;
#
#
#
#
#             var circle_marker_849d8a9a2d51408be6ca75070040ac9b = L

# %% [markdown]
# ## Real Weather Data Integration

# %%
# Load real weather station data and create an interactive map
try:
    import dask.dataframe as dd
    
    # Load station data
    stations_df = dd.read_parquet("../weather_info/stations_dask.parquet")
    stations_sample = stations_df.head(100).compute()  # Get first 100 stations
    
    # Create map
    m6 = folium.Map(location=[39.8283, -98.5795], zoom_start=4)
    
    # Add markers for real weather stations
    for idx, station in stations_sample.iterrows():
        popup_text = f"""
        <div style='text-align: center;'>
            <h4>{station['name']}</h4>
            <p><strong>Station ID:</strong> {station['station_id']}</p>
            <p><strong>Location:</strong> {station['latitude']:.4f}, {station['longitude']:.4f}</p>
            <p><strong>Elevation:</strong> {station['elevation']}m</p>
            <p><strong>State:</strong> {station['state']}</p>
        </div>
        """
        
        # Color based on elevation
        if station['elevation'] > 1000:
            color = 'red'
        elif station['elevation'] > 500:
            color = 'orange'
        else:
            color = 'green'
            
        folium.Marker([station['latitude'], station['longitude']], 
                     popup=popup_text, 
                     icon=folium.Icon(color=color)).add_to(m6)
    
    print(f"Added {len(stations_sample)} real weather stations to the map")
    m6
    
except Exception as e:
    print(f"Could not load real weather data: {e}")
    print("Using sample data instead...")
    
    # Fallback to sample data
    m6 = folium.Map(location=[39.8283, -98.5795], zoom_start=4)
    for station in stations:
        folium.Marker([station['lat'], station['lon']], 
                     popup=f"{station['name']}: {station['temp']}°C").add_to(m6)
    m6
# Out:
# Could not load real weather data: 'DataFrame' object has no attribute 'compute'
# Using sample data instead...

# %% [markdown]
# ## Summary
#
# This demo shows the key features of folium for weather data visualization:
#
# 1. **Basic Maps**: Simple map creation with markers
# 2. **Multiple Markers**: Adding multiple weather stations
# 3. **Color Coding**: Visual indicators based on data values
# 4. **Heatmaps**: Density visualization of temperature data
# 5. **Layers**: Multiple map layers and controls
# 6. **Real Data**: Integration with actual weather station data
#
# ### Key Features Demonstrated:
# - Interactive markers with popups
# - Color-coded visualization
# - Heatmap overlays
# - Multiple map layers
# - Real weather data integration
# - Custom styling and HTML popups
#
# ### Note:
# We switched from pyleaflet to folium because pyleaflet has very limited functionality and doesn't support markers or advanced features. Folium is a much more powerful and feature-rich library for interactive maps.
